# %%
import os
import pandas as pd
from datetime import datetime, date, timedelta
from dateutil.relativedelta import relativedelta
from massive import RESTClient

api_key = os.getenv("MASSIVE_API_KEY")
client = RESTClient(api_key)
TICKER = "SPY"
ADJUSTED = True

def get_last_n_trading_days(symbol: str,
                            n_days: int = 30,
                            lookback_days: int = 90) -> pd.DataFrame:
    """
    Fetch the last n_days trading bars for the given symbol.

    We request a wider calendar window (lookback_days) and then
    keep the most recent n_days trading bars.
    """
    end = date.today()
    start = end - timedelta(days=lookback_days)

    bars = list(
        client.list_aggs(
            ticker=symbol,
            multiplier=1,
            timespan="day",
            from_=start.isoformat(),
            to=end.isoformat(),
            adjusted=ADJUSTED,
            sort="asc",
            limit=50000,
        )
    )

    if not bars:
        raise RuntimeError(
            f"No bars returned for {symbol} between {start} and {end}"
        )

    rows = []
    for b in bars:
        # Massive returns timestamp in ms; convert to UTC date
        trade_dt = datetime.utcfromtimestamp(b.timestamp / 1000).date()
        rows.append(
            {
                "date": trade_dt.isoformat(),
                "open": b.open,
                "high": b.high,
                "low": b.low,
                "close": b.close,
                "volume": b.volume,
            }
        )

    df = pd.DataFrame(rows).sort_values("date")

    # Keep only the last n_days trading sessions
    if len(df) > n_days:
        df = df.tail(n_days)

    df = df.reset_index(drop=True)
    return df


if __name__ == "__main__":
    df = get_last_n_trading_days(TICKER, n_days=30)

    # Save next to current working directory
    out_file = os.path.join(os.getcwd(), "benchmark_history.csv")
    df.to_csv(out_file, index=False)

    print(f"Saved last 30 trading days for {TICKER} to {out_file}")
    print(df)
# Out:
# Fetching last 30 trading days for 1505 symbols (lookback 90 calendar days, ref=2025-11-16)
# ARE: 30 rows
# ALGN: 30 rows
# AOS: 30 rows
# ACN: 30 rows
# ALB: 30 rows
# ALLE: 30 rows
# AMD: 30 rows
# LNT: 30 rows
# ABNB: 30 rows
# GOOGL: 30 rows
# ADBE: 30 rows
# ABBV: 30 rows
# AFL: 30 rows
# ABT: 30 rows
# APD: 30 rows
# AKAM: 30 rows
# MMM: 30 rows
# AES: 30 rows
# ALL: 30 rows
# A: 30 rows
# AIG: 30 rows
# MO: 30 rows
# AMCR: 30 rows
# AEE: 30 rows
# AMT: 30 rows
# AWK: 30 rows
# AEP: 30 rows
# GOOG: 30 rows
# AMGN: 30 rows
# AXP: 30 rows
# AMZN: 30 rows
# ADI: 30 rows
# APA: 30 rows
# APO: 30 rows
# APH: 30 rows
# AON: 30 rows
# AAPL: 30 rows
# AME: 30 rows
# AMAT: 30 rows
# AMP: 30 rows
# ACGL: 30 rows
# APP: 30 rows
# APTV: 30 rows
# ATO: 30 rows
# ANET: 30 rows
# ADM: 30 rows
# AVY: 30 rows
# ADSK: 30 rows
# AIZ: 30 rows
# AVB: 30 rows
# T: 30 rows
# AZO: 30 rows
# BALL: 30 rows
# ADP: 30 rows
# BDX: 30 rows
# AXON: 30 rows
# BKR: 30 rows
# BAC: 30 rows
# BAX: 30 rows
# AJG: 30 rows
# BRK-B: 0 rows
# BBY: 30 rows
# TECH: 30 rows
# BLK: 30 rows
# BX: 30 rows
# BKNG: 30 rows
# BIIB: 30 rows
# BSX: 30 rows
# XYZ: 30 rows
# BR: 30 rows
# BA: 30 rows
# AVGO: 30 rows
# BK: 30 rows
# BLDR: 30 rows
# BF-B: 0 rows
# BRO: 30 rows
# BMY: 30 rows
# BG: 30 rows
# CHRW: 30 rows
# BXP: 30 rows
# CDNS: 30 rows
# CPB: 30 rows
# CPT: 30 rows
# COF: 30 rows
# CAH: 30 rows
# CARR: 30 rows
# CCL: 30 rows
# CAT: 30 rows
# CBRE: 30 rows
# CDW: 30 rows
# CNC: 30 rows
# COR: 30 rows
# SCHW: 30 rows
# CRL: 30 rows
# CHTR: 30 rows
# CVX: 30 rows
# CBOE: 30 rows
# CF: 30 rows
# CNP: 30 rows
# CMG: 30 rows
# CB: 30 rows
# CI: 30 rows
# CHD: 30 rows
# CTAS: 30 rows
# CINF: 30 rows
# CSCO: 30 rows
# C: 30 rows
# CFG: 30 rows
# CME: 30 rows
# CMS: 30 rows
# CTSH: 30 rows
# KO: 30 rows
# CLX: 30 rows
# CAG: 30 rows
# ED: 30 rows
# CL: 30 rows
# COP: 30 rows
# STZ: 30 rows
# CMCSA: 30 rows
# COIN: 30 rows
# CEG: 30 rows
# GLW: 30 rows
# COO: 30 rows
# CPRT: 30 rows
# CPAY: 30 rows
# CTVA: 30 rows
# CSGP: 30 rows
# COST: 30 rows
# CRWD: 30 rows
# CTRA: 30 rows
# CVS: 30 rows
# CSX: 30 rows
# CMI: 30 rows
# CCI: 30 rows
# DAY: 30 rows
# DDOG: 30 rows
# DRI: 30 rows
# DECK: 30 rows
# DHR: 30 rows
# DVA: 30 rows
# DE: 30 rows
# DELL: 30 rows
# DAL: 30 rows
# DXCM: 30 rows
# DVN: 30 rows
# DG: 30 rows
# DLR: 30 rows
# FANG: 30 rows
# DLTR: 30 rows
# D: 30 rows
# DPZ: 30 rows
# DASH: 30 rows
# DOV: 30 rows
# DTE: 30 rows
# DOW: 30 rows
# DD: 30 rows
# DUK: 30 rows
# ETN: 30 rows
# DHI: 30 rows
# EMN: 30 rows
# EBAY: 30 rows
# ECL: 30 rows
# EIX: 30 rows
# EA: 30 rows
# ELV: 30 rows
# EME: 30 rows
# ETR: 30 rows
# EW: 30 rows
# EMR: 30 rows
# EOG: 30 rows
# EPAM: 30 rows
# EFX: 30 rows
# EQT: 30 rows
# EQIX: 30 rows
# ESS: 30 rows
# ERIE: 30 rows
# EVRG: 30 rows
# EQR: 30 rows
# EG: 30 rows
# EL: 30 rows
# ES: 30 rows
# EXE: 30 rows
# EXC: 30 rows
# EXPD: 30 rows
# FICO: 30 rows
# XOM: 30 rows
# FDS: 30 rows
# EXR: 30 rows
# EXPE: 30 rows
# FFIV: 30 rows
# FAST: 30 rows
# FRT: 30 rows
# FDX: 30 rows
# FIS: 30 rows
# FITB: 30 rows
# FSLR: 30 rows
# FE: 30 rows
# F: 30 rows
# FI: 30 rows
# FTNT: 30 rows
# FTV: 30 rows
# FOXA: 30 rows
# FOX: 30 rows
# GRMN: 30 rows
# BEN: 30 rows
# FCX: 30 rows
# GEHC: 30 rows
# GEV: 30 rows
# GEN: 30 rows
# GE: 30 rows
# IT: 30 rows
# GNRC: 30 rows
# GD: 30 rows
# GIS: 30 rows
# GM: 30 rows
# GILD: 30 rows
# GPC: 30 rows
# GPN: 30 rows
# GL: 30 rows
# GDDY: 30 rows
# GS: 30 rows
# HIG: 30 rows
# HAL: 30 rows
# HAS: 30 rows
# HCA: 30 rows
# HSIC: 30 rows
# DOC: 30 rows
# HSY: 30 rows
# HPE: 30 rows
# HLT: 30 rows
# HD: 30 rows
# HOLX: 30 rows
# HON: 30 rows
# HST: 30 rows
# HRL: 30 rows
# HWM: 30 rows
# HPQ: 30 rows
# HUM: 30 rows
# HUBB: 30 rows
# HBAN: 30 rows
# HII: 30 rows
# IEX: 30 rows
# IBM: 30 rows
# IDXX: 30 rows
# ITW: 30 rows
# INCY: 30 rows
# IR: 30 rows
# IBKR: 30 rows
# PODD: 30 rows
# IFF: 30 rows
# INTC: 30 rows
# ICE: 30 rows
# IP: 30 rows
# IPG: 30 rows
# ISRG: 30 rows
# INTU: 30 rows
# INVH: 30 rows
# IVZ: 30 rows
# IRM: 30 rows
# IQV: 30 rows
# JBHT: 30 rows
# JBL: 30 rows
# JKHY: 30 rows
# J: 30 rows
# JNJ: 30 rows
# JCI: 30 rows
# JPM: 30 rows
# KEY: 30 rows
# K: 30 rows
# KDP: 30 rows
# KVUE: 30 rows
# KMB: 30 rows
# KKR: 30 rows
# KIM: 30 rows
# KMI: 30 rows
# KEYS: 30 rows
# KLAC: 30 rows
# KHC: 30 rows
# KR: 30 rows
# LHX: 30 rows
# LH: 30 rows
# LW: 30 rows
# LRCX: 30 rows
# LDOS: 30 rows
# LVS: 30 rows
# LEN: 30 rows
# LII: 30 rows
# LLY: 30 rows
# LYV: 30 rows
# LMT: 30 rows
# LOW: 30 rows
# LIN: 30 rows
# LKQ: 30 rows
# L: 30 rows
# LULU: 30 rows
# LYB: 30 rows
# MTB: 30 rows
# MAR: 30 rows
# MMC: 30 rows
# MPC: 30 rows
# MLM: 30 rows
# MA: 30 rows
# MAS: 30 rows
# MTCH: 30 rows
# MKC: 30 rows
# MCK: 30 rows
# MCD: 30 rows
# MRK: 30 rows
# MDT: 30 rows
# META: 30 rows
# MGM: 30 rows
# MET: 30 rows
# MTD: 30 rows
# MSFT: 30 rows
# MOH: 30 rows
# MRNA: 30 rows
# MCHP: 30 rows
# MU: 30 rows
# MAA: 30 rows
# MHK: 30 rows
# TAP: 30 rows
# MOS: 30 rows
# MNST: 30 rows
# MPWR: 30 rows
# MDLZ: 30 rows
# MCO: 30 rows
# MS: 30 rows
# MSI: 30 rows
# MSCI: 30 rows
# NTAP: 30 rows
# NEM: 30 rows
# NDAQ: 30 rows
# NFLX: 30 rows
# NWSA: 30 rows
# NWS: 30 rows
# NEE: 30 rows
# NI: 30 rows
# NSC: 30 rows
# NKE: 30 rows
# NDSN: 30 rows
# NTRS: 30 rows
# NOC: 30 rows
# NCLH: 30 rows
# NUE: 30 rows
# NRG: 30 rows
# NVDA: 30 rows
# NXPI: 30 rows
# NVR: 30 rows
# ORLY: 30 rows
# OXY: 30 rows
# ODFL: 30 rows
# OMC: 30 rows
# ON: 30 rows
# OKE: 30 rows
# ORCL: 30 rows
# PCAR: 30 rows
# OTIS: 30 rows
# PLTR: 30 rows
# PANW: 30 rows
# PKG: 30 rows
# PSKY: 30 rows
# PAYC: 30 rows
# PYPL: 30 rows
# PEP: 30 rows
# PH: 30 rows
# PNR: 30 rows
# PFE: 30 rows
# PAYX: 30 rows
# PCG: 30 rows
# PM: 30 rows
# PSX: 30 rows
# PNC: 30 rows
# PNW: 30 rows
# POOL: 30 rows
# PPG: 30 rows
# PPL: 30 rows
# PFG: 30 rows
# PGR: 30 rows
# PG: 30 rows
# PLD: 30 rows
# PRU: 30 rows
# PEG: 30 rows
# RTX: 30 rows
# O: 30 rows
# REG: 30 rows
# PSA: 30 rows
# RF: 30 rows
# DGX: 30 rows
# RL: 30 rows
# PWR: 30 rows
# PTC: 30 rows
# QCOM: 30 rows
# PHM: 30 rows
# REGN: 30 rows
# RJF: 30 rows
# RSG: 30 rows
# RMD: 30 rows
# ROK: 30 rows
# HOOD: 30 rows
# RVTY: 30 rows
# ROL: 30 rows
# ROP: 30 rows
# ROST: 30 rows
# RCL: 30 rows
# SPGI: 30 rows
# CRM: 30 rows
# SBAC: 30 rows
# SWKS: 30 rows
# NOW: 30 rows
# SLB: 30 rows
# STX: 30 rows
# SPG: 30 rows
# SRE: 30 rows
# SHW: 30 rows
# SJM: 30 rows
# SW: 30 rows
# SNA: 30 rows
# SOLV: 30 rows
# SOLS: 12 rows
# SO: 30 rows
# LUV: 30 rows
# SWK: 30 rows
# SBUX: 30 rows
# STT: 30 rows
# STE: 30 rows
# STLD: 30 rows
# SYK: 30 rows
# SNPS: 30 rows
# TMUS: 30 rows
# SYY: 30 rows
# TPR: 30 rows
# SYF: 30 rows
# TROW: 30 rows
# SMCI: 30 rows
# TTWO: 30 rows
# TRGP: 30 rows
# TGT: 30 rows
# TER: 30 rows
# TEL: 30 rows
# TDY: 30 rows
# TSLA: 30 rows
# TXN: 30 rows
# TPL: 30 rows
# TXT: 30 rows
# TMO: 30 rows
# TJX: 30 rows
# TTD: 30 rows
# TKO: 30 rows
# TT: 30 rows
# TSCO: 30 rows
# TRMB: 30 rows
# TDG: 30 rows
# TFC: 30 rows
# TYL: 30 rows
# TSN: 30 rows
# TRV: 30 rows
# USB: 30 rows
# ULTA: 30 rows
# UBER: 30 rows
# UDR: 30 rows
# UNP: 30 rows
# UAL: 30 rows
# URI: 30 rows
# UPS: 30 rows
# UNH: 30 rows
# UHS: 30 rows
# VLO: 30 rows
# VTR: 30 rows
# VRSN: 30 rows
# VLTO: 30 rows
# VRTX: 30 rows
# VZ: 30 rows
# VTRS: 30 rows
# VRSK: 30 rows
# VICI: 30 rows
# VST: 30 rows
# V: 30 rows
# VMC: 30 rows
# WRB: 30 rows
# GWW: 30 rows
# WAB: 30 rows
# WMT: 30 rows
# WBD: 30 rows
# WM: 30 rows
# WAT: 30 rows
# DIS: 30 rows
# WFC: 30 rows
# WEC: 30 rows
# WST: 30 rows
# WELL: 30 rows
# WDC: 30 rows
# WY: 30 rows
# WSM: 30 rows
# WTW: 30 rows
# WMB: 30 rows
# WYNN: 30 rows
# WDAY: 30 rows
# XEL: 30 rows
# YUM: 30 rows
# XYL: 30 rows
# ZBRA: 30 rows
# ZBH: 30 rows
# ZTS: 30 rows
# AA: 30 rows
# AAL: 30 rows
# ACI: 30 rows
# AAON: 30 rows
# ACM: 30 rows
# ADC: 30 rows
# AFG: 30 rows
# AGCO: 30 rows
# AIT: 30 rows
# ALE: 30 rows
# ALGM: 30 rows
# ALK: 30 rows
# ALLY: 30 rows
# AM: 30 rows
# ALV: 30 rows
# AMH: 30 rows
# AMG: 30 rows
# AMKR: 30 rows
# AN: 30 rows
# APG: 30 rows
# ANF: 30 rows
# APPF: 30 rows
# AR: 30 rows
# ARW: 30 rows
# ARMK: 30 rows
# ASGN: 30 rows
# ASB: 30 rows
# ASH: 30 rows
# ATI: 30 rows
# AVT: 30 rows
# AVNT: 30 rows
# ATR: 30 rows
# AVAV: 30 rows
# AVTR: 30 rows
# AXTA: 30 rows
# BBWI: 30 rows
# AYI: 30 rows
# BC: 30 rows
# BCO: 30 rows
# BDC: 30 rows
# BHF: 30 rows
# BJ: 30 rows
# BLD: 30 rows
# BKH: 30 rows
# BIO: 30 rows
# BLKB: 30 rows
# BILL: 30 rows
# BMRN: 30 rows
# BRBR: 30 rows
# BRX: 30 rows
# BSY: 30 rows
# BRKR: 30 rows
# BYD: 30 rows
# BWXT: 30 rows
# BURL: 30 rows
# CACI: 30 rows
# CADE: 30 rows
# CAR: 30 rows
# CART: 30 rows
# CASY: 30 rows
# CAVA: 30 rows
# CBT: 30 rows
# CCK: 30 rows
# CFR: 30 rows
# CELH: 30 rows
# CDP: 30 rows
# CBSH: 30 rows
# CGNX: 30 rows
# CG: 30 rows
# CHE: 30 rows
# CHH: 30 rows
# CLF: 30 rows
# CHDN: 30 rows
# CHWY: 30 rows
# CIEN: 30 rows
# CHRD: 30 rows
# CIVI: 30 rows
# CLH: 30 rows
# CMA: 30 rows
# CMC: 30 rows
# CNM: 30 rows
# CNH: 30 rows
# CNO: 30 rows
# COKE: 30 rows
# CNX: 30 rows
# COHR: 30 rows
# CNXC: 30 rows
# COLM: 30 rows
# COLB: 30 rows
# CPRI: 30 rows
# COTY: 30 rows
# CR: 30 rows
# CRS: 30 rows
# CUBE: 30 rows
# CROX: 30 rows
# CSL: 30 rows
# CRUS: 30 rows
# CUZ: 30 rows
# CVLT: 30 rows
# CW: 30 rows
# CXT: 30 rows
# CYTK: 30 rows
# DAR: 30 rows
# DCI: 30 rows
# DINO: 30 rows
# DKS: 30 rows
# DLB: 30 rows
# DBX: 30 rows
# DOCS: 30 rows
# DT: 30 rows
# DOCU: 30 rows
# DTM: 30 rows
# EHC: 30 rows
# ELAN: 30 rows
# DUOL: 30 rows
# EEFT: 30 rows
# EGP: 30 rows
# ELF: 30 rows
# ELS: 30 rows
# ENS: 30 rows
# ENTG: 30 rows
# EPR: 30 rows
# ENSG: 30 rows
# EQH: 30 rows
# EWBC: 30 rows
# EVR: 30 rows
# ESAB: 30 rows
# EXEL: 30 rows
# ESNT: 30 rows
# EXLS: 30 rows
# EXP: 30 rows
# EXPO: 30 rows
# FAF: 30 rows
# FFIN: 30 rows
# FBIN: 30 rows
# FCFS: 30 rows
# FCN: 30 rows
# FHI: 30 rows
# FHN: 30 rows
# FLG: 30 rows
# FIX: 30 rows
# FLEX: 30 rows
# FIVE: 30 rows
# FLR: 30 rows
# FND: 30 rows
# FN: 30 rows
# FLO: 30 rows
# FNB: 30 rows
# FLS: 30 rows
# FOUR: 30 rows
# FNF: 30 rows
# FR: 30 rows
# FTI: 30 rows
# FYBR: 30 rows
# G: 30 rows
# GATX: 30 rows
# GBCI: 30 rows
# GAP: 30 rows
# GEF: 30 rows
# GGG: 30 rows
# GLPI: 30 rows
# GME: 30 rows
# GHC: 30 rows
# GMED: 30 rows
# GPK: 30 rows
# GNTX: 30 rows
# GT: 30 rows
# GTLS: 30 rows
# GTM: 30 rows
# H: 30 rows
# GXO: 30 rows
# GWRE: 30 rows
# HAE: 30 rows
# HALO: 30 rows
# HGV: 30 rows
# HIMS: 30 rows
# HLI: 30 rows
# HLNE: 30 rows
# HOG: 30 rows
# HOMB: 30 rows
# HQY: 30 rows
# HR: 30 rows
# HRB: 30 rows
# HWC: 30 rows
# IBOC: 30 rows
# HXL: 30 rows
# IDA: 30 rows
# ILMN: 30 rows
# INGR: 30 rows
# IPGP: 30 rows
# IRT: 30 rows
# IRDM: 30 rows
# ITT: 30 rows
# JAZZ: 30 rows
# JHG: 30 rows
# JEF: 30 rows
# JLL: 30 rows
# KBH: 30 rows
# KBR: 30 rows
# KD: 30 rows
# KEX: 30 rows
# KNSL: 30 rows
# KNX: 30 rows
# KMPR: 30 rows
# KNF: 30 rows
# KRC: 30 rows
# LAMR: 30 rows
# KTOS: 30 rows
# LAD: 30 rows
# KRG: 30 rows
# LEA: 30 rows
# LECO: 30 rows
# LFUS: 30 rows
# LITE: 30 rows
# LOPE: 30 rows
# LIVN: 30 rows
# LNW: 30 rows
# LNTH: 30 rows
# LPX: 30 rows
# LSCC: 30 rows
# LSTR: 30 rows
# M: 30 rows
# MEDP: 30 rows
# MASI: 30 rows
# MANH: 30 rows
# MIDD: 30 rows
# MLI: 30 rows
# MAT: 30 rows
# MMS: 30 rows
# MKSI: 30 rows
# MSA: 30 rows
# MP: 30 rows
# MORN: 30 rows
# MSM: 30 rows
# MTSI: 30 rows
# MTG: 30 rows
# MTDR: 30 rows
# MTN: 30 rows
# MTZ: 30 rows
# MUR: 30 rows
# MUSA: 30 rows
# MZTI: 30 rows
# NFG: 30 rows
# NBIX: 30 rows
# NLY: 30 rows
# NNN: 30 rows
# NEU: 30 rows
# NJR: 30 rows
# NOV: 30 rows
# NOVT: 30 rows
# NSP: 30 rows
# NSA: 30 rows
# NVST: 30 rows
# NTNX: 30 rows
# NVT: 30 rows
# NXST: 30 rows
# NXT: 30 rows
# NWE: 30 rows
# NYT: 30 rows
# OC: 30 rows
# OGE: 30 rows
# OGS: 30 rows
# OHI: 30 rows
# OKTA: 30 rows
# OLN: 30 rows
# ONB: 30 rows
# OLED: 30 rows
# OLLI: 30 rows
# OPCH: 30 rows
# ONTO: 30 rows
# ORI: 30 rows
# OVV: 30 rows
# OSK: 30 rows
# ORA: 30 rows
# PAG: 30 rows
# PB: 30 rows
# PBF: 30 rows
# OZK: 30 rows
# PCH: 30 rows
# PCTY: 30 rows
# PFGC: 30 rows
# PEGA: 30 rows
# PEN: 30 rows
# PK: 30 rows
# PII: 30 rows
# PLNT: 30 rows
# POST: 30 rows
# PNFP: 30 rows
# POR: 30 rows
# PR: 30 rows
# PPC: 30 rows
# PRI: 30 rows
# PRGO: 30 rows
# POWI: 30 rows
# PSN: 30 rows
# PSTG: 30 rows
# PVH: 30 rows
# QLYS: 30 rows
# R: 30 rows
# RBA: 30 rows
# RGA: 30 rows
# RGEN: 30 rows
# REXR: 30 rows
# RBC: 30 rows
# RGLD: 30 rows
# RH: 30 rows
# RLI: 30 rows
# RMBS: 30 rows
# RNR: 30 rows
# RPM: 30 rows
# ROIV: 30 rows
# RRC: 30 rows
# RS: 30 rows
# RRX: 30 rows
# RYAN: 30 rows
# RYN: 30 rows
# SAIA: 30 rows
# SAM: 30 rows
# SAIC: 30 rows
# SATS: 30 rows
# SBRA: 30 rows
# SCI: 30 rows
# SGI: 30 rows
# SF: 30 rows
# SEIC: 30 rows
# SHC: 30 rows
# SFM: 30 rows
# SLAB: 30 rows
# SIGI: 30 rows
# SLGN: 30 rows
# SLM: 30 rows
# SMG: 30 rows
# SNX: 30 rows
# SNV: 30 rows
# SR: 30 rows
# SON: 30 rows
# SSB: 30 rows
# SSD: 30 rows
# ST: 30 rows
# STAG: 30 rows
# SYNA: 30 rows
# STWD: 30 rows
# SWX: 30 rows
# TEX: 30 rows
# TCBI: 30 rows
# THC: 30 rows
# THG: 30 rows
# TKR: 30 rows
# THO: 30 rows
# TLN: 30 rows
# TNL: 30 rows
# TMHC: 30 rows
# TREX: 30 rows
# TOL: 30 rows
# TTC: 30 rows
# TRU: 30 rows
# TTEK: 30 rows
# TXNM: 30 rows
# TWLO: 30 rows
# TXRH: 30 rows
# UA: 30 rows
# UFPI: 30 rows
# UBSI: 30 rows
# UGI: 30 rows
# UAA: 30 rows
# UTHR: 30 rows
# UNM: 30 rows
# VLY: 30 rows
# VC: 30 rows
# VMI: 30 rows
# VOYA: 30 rows
# VAL: 30 rows
# VAC: 30 rows
# USFD: 30 rows
# VFC: 30 rows
# VNO: 30 rows
# VNOM: 30 rows
# VNT: 30 rows
# UMBF: 30 rows
# VVV: 30 rows
# WAL: 30 rows
# WBS: 30 rows
# WCC: 30 rows
# WEX: 30 rows
# WFRD: 30 rows
# WING: 30 rows
# WH: 30 rows
# WLK: 30 rows
# WPC: 30 rows
# WHR: 30 rows
# WTFC: 30 rows
# WWD: 30 rows
# WTRG: 30 rows
# WTS: 30 rows
# WMS: 30 rows
# XRAY: 30 rows
# WMG: 30 rows
# XPO: 30 rows
# WSO: 30 rows
# YETI: 30 rows
# ZION: 30 rows
# AAP: 30 rows
# AAMI: 30 rows
# ABCB: 30 rows
# AAT: 30 rows
# ABG: 30 rows
# ABR: 30 rows
# ACAD: 30 rows
# ACA: 30 rows
# ADAM: 30 rows
# ADMA: 30 rows
# ADNT: 30 rows
# ABM: 30 rows
# ACIW: 30 rows
# ADEA: 30 rows
# ACLS: 30 rows
# ADUS: 30 rows
# ACT: 30 rows
# ACHC: 30 rows
# AEIS: 30 rows
# AEO: 30 rows
# AESI: 30 rows
# AGO: 30 rows
# AGYS: 30 rows
# AHCO: 30 rows
# AIN: 30 rows
# AL: 30 rows
# AIR: 30 rows
# AHH: 30 rows
# AKR: 30 rows
# ALEX: 30 rows
# AMN: 30 rows
# ALKS: 30 rows
# ALGT: 30 rows
# ALG: 30 rows
# ALRM: 30 rows
# AMPH: 30 rows
# AMSF: 30 rows
# AMR: 30 rows
# AMTM: 30 rows
# AMWD: 30 rows
# ANDE: 30 rows
# ANGI: 30 rows
# AORT: 30 rows
# AOSL: 30 rows
# APLE: 30 rows
# ANIP: 30 rows
# APAM: 30 rows
# ARCB: 30 rows
# APOG: 30 rows
# ARI: 30 rows
# ASIX: 30 rows
# ARWR: 30 rows
# ASTE: 30 rows
# AROC: 30 rows
# ARLO: 30 rows
# ARR: 30 rows
# ASO: 30 rows
# ASTH: 30 rows
# ATEN: 30 rows
# ATGE: 30 rows
# AUB: 30 rows
# AVA: 30 rows
# AWI: 30 rows
# AX: 30 rows
# AZZ: 30 rows
# AVNS: 30 rows
# AXL: 30 rows
# AZTA: 30 rows
# AWR: 30 rows
# BANC: 30 rows
# BBT: 30 rows
# BCC: 30 rows
# BDN: 30 rows
# BFS: 30 rows
# BANR: 30 rows
# BFH: 30 rows
# BANF: 30 rows
# BCPC: 30 rows
# BGC: 30 rows
# BHE: 30 rows
# BJRI: 30 rows
# BKE: 30 rows
# BMI: 30 rows
# BKU: 30 rows
# BOH: 30 rows
# BOOT: 30 rows
# BLFS: 30 rows
# BLMN: 30 rows
# BOX: 30 rows
# BL: 30 rows
# BRC: 30 rows
# BTSG: 30 rows
# BTU: 30 rows
# BWA: 30 rows
# BXMT: 30 rows
# CAKE: 30 rows
# CAL: 30 rows
# CALM: 30 rows
# CABO: 30 rows
# CALX: 30 rows
# CARG: 30 rows
# CARS: 30 rows
# CBRL: 30 rows
# CBU: 30 rows
# CCS: 30 rows
# CATY: 30 rows
# CCOI: 30 rows
# CASH: 30 rows
# CE: 30 rows
# CC: 30 rows
# CENT: 30 rows
# CENTA: 30 rows
# CENX: 30 rows
# CERT: 30 rows
# CEVA: 30 rows
# CFFN: 30 rows
# CLB: 30 rows
# CHCO: 30 rows
# CHEF: 30 rows
# CLSK: 30 rows
# CNK: 30 rows
# CNMD: 30 rows
# CNXN: 30 rows
# CRC: 30 rows
# CPRX: 30 rows
# COLL: 30 rows
# CNR: 30 rows
# CORT: 30 rows
# CPF: 30 rows
# COHU: 30 rows
# CRGY: 30 rows
# CPK: 30 rows
# CON: 30 rows
# CRI: 30 rows
# CRK: 30 rows
# CNS: 30 rows
# CRVL: 30 rows
# CRSR: 30 rows
# CSGS: 30 rows
# CSR: 30 rows
# CTKB: 30 rows
# CSW: 30 rows
# CTRE: 30 rows
# CTS: 30 rows
# CWK: 30 rows
# CVI: 30 rows
# CVBF: 30 rows
# CVCO: 30 rows
# CWEN-A: 0 rows
# CURB: 30 rows
# CWEN: 30 rows
# CZR: 30 rows
# CXW: 30 rows
# CUBI: 30 rows
# CXM: 30 rows
# CWT: 30 rows
# DAN: 30 rows
# DCOM: 30 rows
# DEA: 30 rows
# DEI: 30 rows
# DFH: 30 rows
# DFIN: 30 rows
# DGII: 30 rows
# DIOD: 30 rows
# DLX: 30 rows
# DNOW: 30 rows
# DOCN: 30 rows
# DORM: 30 rows
# DRH: 30 rows
# DVAX: 30 rows
# DXPE: 30 rows
# DXC: 30 rows
# EAT: 30 rows
# DV: 30 rows
# DY: 30 rows
# ECG: 30 rows
# ECPG: 30 rows
# EFC: 30 rows
# EGBN: 30 rows
# EIG: 30 rows
# ELME: 30 rows
# EMBC: 30 rows
# ENOV: 30 rows
# ENPH: 30 rows
# ENR: 30 rows
# ENVA: 30 rows
# EPC: 30 rows
# EPRT: 30 rows
# EXPI: 30 rows
# ETD: 30 rows
# ESI: 30 rows
# EVTC: 30 rows
# EZPW: 30 rows
# EXTR: 30 rows
# EPAC: 30 rows
# ETSY: 30 rows
# ESE: 30 rows
# EYE: 30 rows
# FBK: 30 rows
# FBNC: 30 rows
# FBRT: 30 rows
# FBP: 30 rows
# FCF: 30 rows
# FCPT: 30 rows
# FDP: 30 rows
# FELE: 30 rows
# FHB: 30 rows
# FIZZ: 30 rows
# FFBC: 30 rows
# FMC: 30 rows
# FORM: 30 rows
# FSS: 30 rows
# FOXF: 30 rows
# FTRE: 30 rows
# FRPT: 30 rows
# FUL: 30 rows
# FTDR: 30 rows
# FULT: 30 rows
# FUN: 30 rows
# FWRD: 30 rows
# GBX: 30 rows
# GDEN: 30 rows
# GDYN: 30 rows
# GEO: 30 rows
# GES: 30 rows
# GFF: 30 rows
# GIII: 30 rows
# GKOS: 30 rows
# GNL: 30 rows
# GNW: 30 rows
# GO: 30 rows
# GOGO: 30 rows
# GRBK: 30 rows
# GOLF: 30 rows
# GPI: 30 rows
# GSHD: 30 rows
# GVA: 30 rows
# GTES: 30 rows
# GTY: 30 rows
# HAFC: 30 rows
# HASI: 30 rows
# HAYW: 30 rows
# HBI: 30 rows
# HCC: 30 rows
# HCI: 30 rows
# HCSG: 30 rows
# HI: 30 rows
# HFWA: 30 rows
# HELE: 30 rows
# HL: 30 rows
# HIW: 30 rows
# HLIT: 30 rows
# HMN: 30 rows
# HLX: 30 rows
# HNI: 30 rows
# HSTM: 30 rows
# HSII: 30 rows
# HP: 30 rows
# HOPE: 30 rows
# HRMY: 30 rows
# HTH: 30 rows
# HTLD: 30 rows
# HTO: 30 rows
# HTZ: 30 rows
# HWKN: 30 rows
# HUBG: 30 rows
# HZO: 30 rows
# IART: 30 rows
# IAC: 30 rows
# ICHR: 30 rows
# ICUI: 30 rows
# IDCC: 30 rows
# IBP: 30 rows
# IIPR: 30 rows
# IIIN: 30 rows
# INDB: 30 rows
# INSP: 30 rows
# INVA: 30 rows
# INSW: 30 rows
# INN: 30 rows
# IOSP: 30 rows
# INVX: 30 rows
# IPAR: 30 rows
# ITGR: 30 rows
# JBGS: 30 rows
# ITRI: 30 rows
# JBSS: 30 rows
# JBLU: 30 rows
# JBTM: 30 rows
# JJSF: 30 rows
# JXN: 30 rows
# KALU: 30 rows
# JOE: 30 rows
# KAR: 30 rows
# KAI: 30 rows
# KMT: 30 rows
# KFY: 30 rows
# KLIC: 30 rows
# KN: 30 rows
# KGS: 30 rows
# KNTK: 30 rows
# KOP: 30 rows
# KREF: 30 rows
# KRYS: 30 rows
# KSS: 30 rows
# KTB: 30 rows
# KW: 30 rows
# KWR: 30 rows
# LBRT: 30 rows
# LCII: 30 rows
# LEG: 30 rows
# LGIH: 30 rows
# LGND: 30 rows
# LMAT: 30 rows
# LKFN: 30 rows
# LNC: 30 rows
# LQDT: 30 rows
# LNN: 30 rows
# LPG: 30 rows
# LRN: 30 rows
# LUMN: 30 rows
# LTC: 30 rows
# LXP: 30 rows
# LZB: 30 rows
# MAN: 30 rows
# MAC: 30 rows
# MARA: 30 rows
# MBC: 30 rows
# MATX: 30 rows
# MATW: 30 rows
# MC: 30 rows
# MCW: 30 rows
# MCRI: 30 rows
# MD: 30 rows
# MCY: 30 rows
# MDU: 30 rows
# MGEE: 30 rows
# MGY: 30 rows
# MHO: 30 rows
# MGPI: 30 rows
# MKTX: 30 rows
# MIR: 30 rows
# MLKN: 30 rows
# MMI: 30 rows
# MMSI: 30 rows
# MNRO: 30 rows
# MODG: 30 rows
# MPW: 30 rows
# MOG-A: 0 rows
# MRCY: 30 rows
# MRTN: 30 rows
# MSEX: 30 rows
# MRP: 30 rows
# MTH: 30 rows
# MSGS: 30 rows
# MTRN: 30 rows
# MTUS: 30 rows
# MTX: 30 rows
# MWA: 30 rows
# MXL: 30 rows
# MYGN: 30 rows
# MYRG: 30 rows
# NABL: 30 rows
# NATL: 30 rows
# NAVI: 30 rows
# NBHC: 30 rows
# NBTB: 30 rows
# NEO: 30 rows
# NEOG: 30 rows
# NE: 30 rows
# NGVT: 30 rows
# NPO: 30 rows
# NMIH: 30 rows
# NHC: 30 rows
# NPK: 30 rows
# NSIT: 30 rows
# NOG: 30 rows
# NVRI: 30 rows
# NTCT: 30 rows
# NWBI: 30 rows
# NWL: 30 rows
# NWN: 30 rows
# NX: 30 rows
# NXRT: 30 rows
# OGN: 30 rows
# OFG: 30 rows
# OI: 30 rows
# OII: 30 rows
# OMCL: 30 rows
# OSIS: 30 rows
# OTTR: 30 rows
# OUT: 30 rows
# OXM: 30 rows
# PAHC: 30 rows
# PBH: 30 rows
# PAYO: 30 rows
# PARR: 30 rows
# PBI: 30 rows
# PATK: 30 rows
# PCRX: 30 rows
# PDFS: 30 rows
# PEB: 30 rows
# PECO: 30 rows
# PENG: 30 rows
# PENN: 30 rows
# PFS: 30 rows
# PFBC: 30 rows
# PHIN: 30 rows
# PI: 30 rows
# PGNY: 30 rows
# PINC: 30 rows
# PIPR: 30 rows
# PJT: 30 rows
# PLAB: 30 rows
# PLAY: 30 rows
# PLMR: 30 rows
# PLUS: 30 rows
# PLXS: 30 rows
# POWL: 30 rows
# PMT: 30 rows
# PRA: 30 rows
# PRAA: 30 rows
# PRDO: 30 rows
# PRG: 30 rows
# PRKS: 30 rows
# PRK: 30 rows
# PRGS: 30 rows
# PRSU: 30 rows
# PRVA: 30 rows
# PRLB: 30 rows
# PSMT: 30 rows
# PTEN: 30 rows
# PZZA: 30 rows
# PTGX: 30 rows
# QDEL: 30 rows
# QNST: 30 rows
# RAL: 30 rows
# RAMP: 30 rows
# RC: 30 rows
# QTWO: 30 rows
# QRVO: 30 rows
# RCUS: 30 rows
# RDN: 30 rows
# RDNT: 30 rows
# RES: 30 rows
# REYN: 30 rows
# REX: 30 rows
# RHP: 30 rows
# RGR: 30 rows
# RHI: 30 rows
# REZI: 30 rows
# RNST: 30 rows
# ROCK: 30 rows
# ROG: 30 rows
# RUN: 30 rows
# RUSHA: 30 rows
# RWT: 30 rows
# SABR: 30 rows
# SAH: 30 rows
# SAFE: 30 rows
# RXO: 30 rows
# SAFT: 30 rows
# SANM: 30 rows
# SBCF: 30 rows
# SBH: 30 rows
# SBSI: 30 rows
# SCHL: 30 rows
# SDGR: 30 rows
# SEDG: 30 rows
# SCVL: 30 rows
# SCSC: 30 rows
# SCL: 30 rows
# SEE: 30 rows
# SEM: 30 rows
# SFBS: 30 rows
# SFNC: 30 rows
# SHO: 30 rows
# SHAK: 30 rows
# SIG: 30 rows
# SHEN: 30 rows
# SHOO: 30 rows
# SITC: 30 rows
# SITM: 30 rows
# SKT: 30 rows
# SKY: 30 rows
# SKYW: 30 rows
# SLG: 30 rows
# SLVM: 30 rows
# SNCY: 30 rows
# SM: 30 rows
# SMPL: 30 rows
# SMTC: 30 rows
# SNDK: 30 rows
# SMP: 30 rows
# SNDR: 30 rows
# SNEX: 30 rows
# SONO: 30 rows
# SPNT: 30 rows
# SSTK: 30 rows
# SRPT: 30 rows
# SPSC: 30 rows
# SPXC: 30 rows
# STAA: 30 rows
# STBA: 30 rows
# STC: 30 rows
# STEL: 30 rows
# STEP: 30 rows
# SUPN: 30 rows
# SXC: 30 rows
# STRL: 30 rows
# STRA: 30 rows
# SXT: 30 rows
# SXI: 30 rows
# TALO: 30 rows
# TBBK: 30 rows
# TDS: 30 rows
# TDW: 30 rows
# TGNA: 30 rows
# TGTX: 30 rows
# TFX: 30 rows
# TFIN: 30 rows
# THRM: 30 rows
# TDC: 30 rows
# THRY: 30 rows
# THS: 30 rows
# TILE: 30 rows
# TMDX: 30 rows
# TMP: 30 rows
# TNC: 30 rows
# TNDM: 30 rows
# TR: 30 rows
# TRN: 30 rows
# TPH: 30 rows
# TRMK: 30 rows
# TRIP: 30 rows
# TRNO: 30 rows
# TRST: 30 rows
# TTMI: 30 rows
# TWI: 30 rows
# TRUP: 30 rows
# TWO: 30 rows
# UCB: 30 rows
# UCTT: 30 rows
# UE: 30 rows
# UFCS: 30 rows
# UFPT: 30 rows
# UHT: 30 rows
# UNFI: 30 rows
# USPH: 30 rows
# UNIT: 30 rows
# UPBD: 30 rows
# UVV: 30 rows
# UTL: 30 rows
# USNA: 30 rows
# UNF: 30 rows
# URBN: 30 rows
# VCEL: 30 rows
# VCTR: 30 rows
# VICR: 30 rows
# VIAV: 30 rows
# VIR: 30 rows
# VCYT: 30 rows
# VECO: 30 rows
# VIRT: 30 rows
# VRE: 30 rows
# VRTS: 30 rows
# VRRM: 30 rows
# VSH: 30 rows
# VSAT: 30 rows
# VSCO: 30 rows
# VSTS: 30 rows
# VTOL: 30 rows
# VYX: 30 rows
# VTLE: 30 rows
# WAY: 30 rows
# WAFD: 30 rows
# WABC: 30 rows
# WD: 30 rows
# WERN: 30 rows
# WEN: 30 rows
# WGO: 30 rows
# WDFC: 30 rows
# WHD: 30 rows
# WKC: 30 rows
# WLY: 30 rows
# WOR: 30 rows
# WRLD: 30 rows
# WS: 30 rows
# WSFS: 30 rows
# WSC: 30 rows
# WT: 30 rows
# WWW: 30 rows
# XPEL: 30 rows
# XHR: 30 rows
# WU: 30 rows
# XNCR: 30 rows
# WSR: 30 rows
# YELP: 30 rows
# ZWS: 30 rows
# YOU: 30 rows
# ZD: 30 rows
#
# Wrote price history for 1501 symbols and 45012 total rows to sp1500_history_30d.csv
#     symbol        date    open     high     low   close     volume      vwap
# 570      A  2025-10-06  141.51  141.935  139.90  141.61  1538402.0  141.3568
# 571      A  2025-10-07  141.86  142.270  138.44  138.56  1444593.0  139.3369
# 572      A  2025-10-08  140.36  142.440  138.97  140.81  1698819.0  141.3061
# 573      A  2025-10-09  140.28  140.940  138.48  140.11  1149998.0  139.6371
# 574      A  2025-10-10  139.66  140.575  136.29  136.62  1968156.0  137.3252
